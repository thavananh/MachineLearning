# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import style
style.use('ggplot')

# %%
df = pd.read_csv('Position_Salaries.csv')
X = np.array(df.iloc[:, 1:2].values)
y = np.array(df.iloc[:, -1].values)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
from sklearn.ensemble import RandomForestRegressor
r1 = RandomForestRegressor()
r2 = RandomForestRegressor()
r3 = RandomForestRegressor()
r1.fit(X, y)
r2.fit(X, y)
r3.fit(X, y)
# Out:
# RandomForestRegressor()

# %%
r1_train = RandomForestRegressor()
r2_train = RandomForestRegressor()
r3_train = RandomForestRegressor()
r1_train.fit(X_train, y_train)
r2_train.fit(X_train, y_train)
r3_train.fit(X_train, y_train)
# Out:
# RandomForestRegressor()

# %%
plt.title('Random Forest')
plt.scatter(X, y, color='red')
plt.plot(X, r1.predict(X), color='blue')
plt.plot(X, r2.predict(X), color='orange')
plt.plot(X, r3.predict(X), color='yellow')
plt.xlabel('PositionLevel')
plt.ylabel('Salary')
plt.show()

# %%
max_x = max(max(X_train), max(X_test))
X_grid = np.arange(min(X_train), max_x + 0.1, 0.1)
X_grid = X_grid.reshape(len(X_grid), 1)
# Out:
# /tmp/ipykernel_28733/485364061.py:2: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   X_grid = np.arange(min(X_train), max_x + 0.1, 0.1)

# %%
plt.title('Random Forest')
plt.scatter(X_test, y_test, color='red')
plt.plot(X_grid, r1_train.predict(X_grid), color='blue')
plt.plot(X_grid, r2_train.predict(X_grid), color='orange')
plt.plot(X_grid, r3_train.predict(X_grid), color='yellow')
plt.xlabel('PositionLevel')
plt.ylabel('Salary')
plt.show()
